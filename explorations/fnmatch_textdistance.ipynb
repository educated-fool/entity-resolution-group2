# %% [markdown]
# # Step 1: Data Cleaning

# %%
import pandas as pd
left_df = pd.read_csv('../data/left_dataset.csv')
right_df = pd.read_csv('../data/right_dataset.csv')

# %%
print("Missing values in left_df:")
print(left_df.isnull().sum())

print("Missing values in right_df:")
print(right_df.isnull().sum())
# Out:
# Missing values in left_df:
# entity_id         0
# name              0
# address        2798
# city              0
# state             0
# postal_code      37
# categories       62
# dtype: int64
# Missing values in right_df:
# business_id    0
# name           0
# address        0
# city           0
# state          0
# zip_code       0
# size           0
# dtype: int64

# %%
#pip install skimpy

# %%
# Clean and Standardize Postal Codes

# Clean postal_code in left_df by converting to integer
left_df['postal_code'] = left_df['postal_code'].fillna(0).astype(int).astype(str)

# Clean postal_code in right_df by slicing to keep only the first 5 digits
right_df['zip_code'] = right_df['zip_code'].str.slice(0, 5)

# %%
# Convert all columns to string
left_df = left_df.astype(str)
right_df = right_df.astype(str)

# %%
def clean_dataframe(df):
    def clean_text_column(column):
        column = column.str.lower()  # Convert to lower case
        column = column.str.replace(r'[^\w\s]', '', regex=True)  # Remove punctuation
        column = column.str.strip()  # Strip whitespaces
        return column
    # Apply the cleaning function to each column in the DataFrame that is of object type
    for column in df.columns:
        if df[column].dtype == 'object':
            df[column] = clean_text_column(df[column])
    return df

# %%
left_df = clean_dataframe(left_df)
right_df = clean_dataframe(right_df)

# %%
from skimpy import skim
skim(left_df)
skim(right_df)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 94585  │ │ string      │ 7     │                                                          │
# │ │ Number of columns │ 7      │ └─────────────┴───────┘                                                          │
# │ └───────────────────┴────────┘                                                                                  │
# │                                                     string                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┓  │
# │ ┃ column_name               ┃ NA      ┃ NA %       ┃ words per row                ┃ total words              ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━┩  │
# │ │ entity_id                 │       0 │          0 │                            1 │                    94585 │  │
# │ │ name                      │       0 │          0 │                          3.1 │                   290007 │  │
# │ │ address                   │       0 │          0 │                          3.9 │                   364978 │  │
# │ │ city                      │       0 │          0 │                          1.3 │                   120535 │  │
# │ │ state                     │       0 │          0 │                            1 │                    94585 │  │
# │ │ postal_code               │       0 │          0 │                            1 │                    94585 │  │
# │ │ categories                │       0 │          0 │                          7.8 │                   742122 │  │
# │ └───────────────────────────┴─────────┴────────────┴──────────────────────────────┴──────────────────────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 91791  │ │ string      │ 7     │                                                          │
# │ │ Number of columns │ 7      │ └─────────────┴───────┘                                                          │
# │ └───────────────────┴────────┘                                                                                  │
# │                                                     string                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┓  │
# │ ┃ column_name               ┃ NA      ┃ NA %       ┃ words per row                ┃ total words              ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━┩  │
# │ │ business_id               │       0 │          0 │                            1 │                    91791 │  │
# │ │ name                      │       0 │          0 │                          3.8 │                   351838 │  │
# │ │ address                   │       0 │          0 │                          4.1 │                   372689 │  │
# │ │ city                      │       0 │          0 │                          1.3 │                   115386 │  │
# │ │ state                     │       0 │          0 │                            1 │                    91791 │  │
# │ │ zip_code                  │       0 │          0 │                            1 │                    91791 │  │
# │ │ size                      │       0 │          0 │                            1 │                    91791 │  │
# │ └───────────────────────────┴─────────┴────────────┴──────────────────────────────┴──────────────────────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯

# %%
left_df.head()
# Out:
#   entity_id                      name  \
# 0         1             the ups store
# 1         2        st honore pastries
# 2         3  perkiomen valley brewery
# 3         4             sonic drivein
# 4         5           famous footwear
#
#                                      address          city state postal_code  \
# 0            87 grasso plaza shopping center        affton    mo       63123
# 1                                935 race st  philadelphia    pa       19107
# 2                              101 walnut st    green lane    pa       18054
# 3                              615 s main st  ashland city    tn       37015
# 4  8522 eager road dierbergs brentwood point     brentwood    mo       63144
#
#                                           categories
# 0  shipping centers local services notaries mailb...
# 1   restaurants food bubble tea coffee  tea bakeries
# 2                            brewpubs breweries food
# 3  burgers fast food sandwiches food ice cream  f...
# 4  sporting goods fashion shoe stores shopping sp...

# %%
right_df.head()
# Out:
#   business_id                              name                      address  \
# 0           1              sourini painting inc              12800 44th st n
# 1           2              wolff dolla bill llc              1905 e 19th ave
# 2           3  comprehensive surgery center llc  1988 gulf to bay blvd ste 1
# 3           4           frank  adam apparel llc             13640 wright cir
# 4           5         moreno plus transport inc    8608 huron court unite 58
#
#          city state zip_code size
# 0  clearwater    fl    33762  110
# 1       tampa    fl    33605   80
# 2  clearwater    fl    33765   80
# 3       tampa    fl    33626  120
# 4       tampa    fl    33614   80

# %% [markdown]
# # Step2: Blocking

# %% [markdown]
# ## Create Combined Blocking Key

# %%
# Combine state, first letter of address, first letter of name, 
# first 3 letters of postal_code/zip_code to create a blocking key

left_df['block_key'] = (left_df['state'] + " " +
                        left_df['address'].str[0] + " " +  # First letter of address
                        left_df['name'].str[0] + " " +  # First letter of name
                        left_df['postal_code'].str[:3])  # First 3 letters of postal_code

right_df['block_key'] = (right_df['state'] + " " +
                         right_df['address'].str[0] + " " +  # First letter of address
                         right_df['name'].str[0] + " " +  # First letter of name
                         right_df['zip_code'].str[:3])  # First 3 letters of postal_code

# %%
left_df.head()
# Out:
#   entity_id                      name  \
# 0         1             the ups store
# 1         2        st honore pastries
# 2         3  perkiomen valley brewery
# 3         4             sonic drivein
# 4         5           famous footwear
#
#                                      address          city state postal_code  \
# 0            87 grasso plaza shopping center        affton    mo       63123
# 1                                935 race st  philadelphia    pa       19107
# 2                              101 walnut st    green lane    pa       18054
# 3                              615 s main st  ashland city    tn       37015
# 4  8522 eager road dierbergs brentwood point     brentwood    mo       63144
#
#                                           categories   block_key
# 0  shipping centers local services notaries mailb...  mo 8 t 631
# 1   restaurants food bubble tea coffee  tea bakeries  pa 9 s 191
# 2                            brewpubs breweries food  pa 1 p 180
# 3  burgers fast food sandwiches food ice cream  f...  tn 6 s 370
# 4  sporting goods fashion shoe stores shopping sp...  mo 8 f 631

# %%
right_df.head()
# Out:
#   business_id                              name                      address  \
# 0           1              sourini painting inc              12800 44th st n
# 1           2              wolff dolla bill llc              1905 e 19th ave
# 2           3  comprehensive surgery center llc  1988 gulf to bay blvd ste 1
# 3           4           frank  adam apparel llc             13640 wright cir
# 4           5         moreno plus transport inc    8608 huron court unite 58
#
#          city state zip_code size   block_key
# 0  clearwater    fl    33762  110  fl 1 s 337
# 1       tampa    fl    33605   80  fl 1 w 336
# 2  clearwater    fl    33765   80  fl 1 c 337
# 3       tampa    fl    33626  120  fl 1 f 336
# 4       tampa    fl    33614   80  fl 8 m 336

# %% [markdown]
# ## Reduce the Dataset Size by Blocking
# Using the blocking key, merge the two datasets. This will significantly reduce the number of rows to compare.

# %%
# Perform an inner join on the blocking key
blocked_pairs = pd.merge(left_df, right_df, on='block_key', suffixes=('_left', '_right'))

# %%
blocked_pairs.head()
# Out:
#   entity_id      name_left                     address_left city_left  \
# 0         1  the ups store  87 grasso plaza shopping center    affton
# 1         1  the ups store  87 grasso plaza shopping center    affton
# 2         1  the ups store  87 grasso plaza shopping center    affton
# 3         1  the ups store  87 grasso plaza shopping center    affton
# 4         1  the ups store  87 grasso plaza shopping center    affton
#
#   state_left postal_code                                         categories  \
# 0         mo       63123  shipping centers local services notaries mailb...
# 1         mo       63123  shipping centers local services notaries mailb...
# 2         mo       63123  shipping centers local services notaries mailb...
# 3         mo       63123  shipping centers local services notaries mailb...
# 4         mo       63123  shipping centers local services notaries mailb...
#
#     block_key business_id                   name_right  \
# 0  mo 8 t 631       36646           tie consulting llc
# 1  mo 8 t 631       37027  the art of entertaining inc
# 2  mo 8 t 631       37156     the kohn partnership llp
# 3  mo 8 t 631       37159    the schechter law firm pc
# 4  mo 8 t 631       37162    the schechter law firm pc
#
#                  address_right   city_right state_right zip_code size
# 0        8025 bonhomme ave 807  saint louis          mo    63105   30
# 1           8796 big bend blvd  saint louis          mo    63119  250
# 2  8251 maryland ave suite 108  saint louis          mo    63105   90
# 3    8000 maryland ave ste 950  saint louis          mo    63105   90
# 4      8000 maryland suite 950     st louis          mo    63105   90

# %% [markdown]
# # Step 3: Apply fnmatch for Matching and textdistance for Similarity Score

# %%
import fnmatch
import textdistance

# Define a function that uses both fnmatch and textdistance to calculate a confidence score
def calculate_confidence(name_left, name_right):
    # Check for exact match using fnmatch
    if name_left == name_right:
        return 1.0
    # If names are similar according to fnmatch
    elif fnmatch.fnmatch(name_left, f"*{name_right}*") or fnmatch.fnmatch(name_right, f"*{name_left}*"):
        # Use Jaro-Winkler similarity
        # It's a good choice after an fnmatch wildcard match because it can handle small discrepancies well.
        similarity = textdistance.jaro_winkler(name_left, name_right)
        # Boost the confidence score by a factor, since fnmatch has found a wildcard match
        # The reason for the boost is to differentiate between cases where fnmatch has already found 
        # some level of similarity (this case) and those where we're solely relying on the similarity score from textdistance.
        # The boost of 1.2 is a just a guess
        return min(similarity * 1.2, 1.0)
    else:
        # Uses Jaccard index for a similarity score if we did not find a wildcard match
        # It's a measure of how many elements two sets have in common.
        similarity = textdistance.jaccard(name_left, name_right)
        return similarity

# Apply the function to each row of the blocked_pairs dataframe
blocked_pairs['confidence_score'] = blocked_pairs.apply(
    lambda row: calculate_confidence(row['name_left'].lower(), row['name_right'].lower()), axis=1
)

# Filter out the matches with a confidence score above the threshold
high_confidence_matches = blocked_pairs[blocked_pairs['confidence_score'] > 0.8]
high_confidence_matches
# Out:
#         entity_id                 name_left          address_left  \
# 251             8             sonic drivein   2312 dickerson pike
# 293             8             sonic drivein   2312 dickerson pike
# 950            15                       bap         1224 south st
# 3561           57                james dant  5624 e washington st
# 3707           60                   tko djs       2650 s big bend
# ...           ...                       ...                   ...
# 6837734     94475          rudys sports bar         11100 66th st
# 6837742     94475          rudys sports bar         11100 66th st
# 6842155     94539        sage mediterranean         150 bridge st
# 6842431     94546            plantation pub  8321 sawyer brown rd
# 6844985     94579  shanti yoga and ayurveda     1638 pine st fl 1
#
#             city_left state_left postal_code  \
# 251         nashville         tn       37207
# 293         nashville         tn       37207
# 950      philadelphia         pa       19147
# 3561     indianapolis         in       46219
# 3707        maplewood         mo       63143
# ...               ...        ...         ...
# 6837734         largo         fl       33773
# 6837742         largo         fl       33773
# 6842155  phoenixville         pa       19460
# 6842431      bellevue         tn       37221
# 6844985  philadelphia         pa       19103
#
#                                                 categories   block_key  \
# 251      ice cream  frozen yogurt fast food burgers res...  tn 2 s 372
# 293      ice cream  frozen yogurt fast food burgers res...  tn 2 s 372
# 950                                     korean restaurants  pa 1 b 191
# 3561                        fashion shopping mens clothing  in 5 j 462
# 3707     karaoke djs event planning  services party  ev...  mo 2 t 631
# ...                                                    ...         ...
# 6837734  restaurants pizza nightlife sports bars bars a...  fl 1 r 337
# 6837742  restaurants pizza nightlife sports bars bars a...  fl 1 r 337
# 6842155                          restaurants mediterranean  pa 1 s 194
# 6842431                    sports bars nightlife pubs bars  tn 8 p 372
# 6844985  health  medical yoga shopping naturopathicholi...  pa 1 s 191
#
#         business_id                                  name_right  \
# 251           81912         sonic drivein nashville melrose llc
# 293           84021  sonic drivein nashville dickerson road llc
# 950           57146                    bible way baptist church
# 3561          32737                              james dant llc
# 3707          39159                                 tko djs inc
# ...             ...                                         ...
# 6837734         166                       rudys sports bar  llc
# 6837742        2373                        rudys sports bar llc
# 6842155       79363              sage mediterranean cuisine inc
# 6842431       83310                          plantation pub inc
# 6844985       80357                shanti yoga and ayurveda llc
#
#                 address_right    city_right state_right zip_code size  \
# 251        2501 franklin road     nashville          tn    37204  240
# 293       2312 dickerson road     nashville          tn    37207  210
# 950        1323 n 52nd street  philadelphia          pa    19131  110
# 3561     5624 e washington st  indianapolis          in    46219   60
# 3707     2650 s big bend blvd      st louis          mo    63143  250
# ...                       ...           ...         ...      ...  ...
# 6837734         11100 66th st         largo          fl    33773  180
# 6837742         11100 66th st         largo          fl    33773  180
# 6842155         150 bridge st  phoenixville          pa    19460   40
# 6842431  8321 sawyer brown rd     nashville          tn    37221  300
# 6844985   1638 pine sr 1st fl  philadelphia          pa    19103   80
#
#          confidence_score
# 251                 1.000
# 293                 1.000
# 950                 0.885
# 3561                1.000
# 3707                1.000
# ...                   ...
# 6837734             1.000
# 6837742             1.000
# 6842155             1.000
# 6842431             1.000
# 6844985             1.000
#
# [8003 rows x 16 columns]

# %% [markdown]
# # Step 4: Write the Result to a CSV

# %%
high_confidence_matches = high_confidence_matches.rename(columns={'entity_id': 'left_dataset', 'business_id': 'right_dataset'})

# %%
# Prepare the final matches output with selected columns
output_columns = ['left_dataset', 'right_dataset', 'confidence_score']

# %%
high_confidence_matches[output_columns]
# Out:
#         left_dataset right_dataset  confidence_score
# 251                8         81912             1.000
# 293                8         84021             1.000
# 950               15         57146             0.885
# 3561              57         32737             1.000
# 3707              60         39159             1.000
# ...              ...           ...               ...
# 6837734        94475           166             1.000
# 6837742        94475          2373             1.000
# 6842155        94539         79363             1.000
# 6842431        94546         83310             1.000
# 6844985        94579         80357             1.000
#
# [8003 rows x 3 columns]

# %%
high_confidence_matches[output_columns].to_csv('high_confidence_matches_fnmatch_textdistance.csv', index=False)
