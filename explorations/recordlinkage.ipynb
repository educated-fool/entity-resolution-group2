# %%
#! pip install recordlinkage

# %%
import pandas as pd
left_df = pd.read_csv('../data/left_dataset.csv')
right_df = pd.read_csv('../data/right_dataset.csv')

# %%
print("Missing values in left_df:")
print(left_df.isnull().sum())

print("Missing values in right_df:")
print(right_df.isnull().sum())
# Out:
# Missing values in left_df:
# entity_id         0
# name              0
# address        2798
# city              0
# state             0
# postal_code      37
# categories       62
# dtype: int64
# Missing values in right_df:
# business_id    0
# name           0
# address        0
# city           0
# state          0
# zip_code       0
# size           0
# dtype: int64

# %%
from skimpy import skim
skim(left_df)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 94585  │ │ string      │ 5     │                                                          │
# │ │ Number of columns │ 7      │ │ int64       │ 1     │                                                          │
# │ └───────────────────┴────────┘ │ float64     │ 1     │                                                          │
# │                                └─────────────┴───────┘                                                          │
# │                                                     number                                                      │
# │ ┏━━━━━━━━━━━━━━━━┳━━━━━┳━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┓  │
# │ ┃ column_name    ┃ NA  ┃ NA %   ┃ mean    ┃ sd      ┃ p0     ┃ p25     ┃ p50    ┃ p75    ┃ p100    ┃ hist    ┃  │
# │ ┡━━━━━━━━━━━━━━━━╇━━━━━╇━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━╇━━━━━━━━╇━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━┩  │
# │ │ entity_id      │   0 │      0 │   47000 │   27000 │      1 │   24000 │  47000 │  71000 │   95000 │ ▇▇▇▇▇▇  │  │
# │ │ postal_code    │  37 │   0.04 │   34000 │   14000 │   1900 │   19000 │  34000 │  37000 │  340000 │   ▇▁    │  │
# │ └────────────────┴─────┴────────┴─────────┴─────────┴────────┴─────────┴────────┴────────┴─────────┴─────────┘  │
# │                                                     string                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━┓  │
# │ ┃ column_name              ┃ NA         ┃ NA %       ┃ words per row               ┃ total words             ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━┩  │
# │ │ name                     │          0 │          0 │                         3.1 │                  290127 │  │
# │ │ address                  │       2798 │       2.96 │                         3.8 │                  362194 │  │
# │ │ city                     │          0 │          0 │                         1.3 │                  120562 │  │
# │ │ state                    │          0 │          0 │                           1 │                   94585 │  │
# │ │ categories               │         62 │       0.07 │                         7.8 │                  742060 │  │
# │ └──────────────────────────┴────────────┴────────────┴─────────────────────────────┴─────────────────────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯

# %%
skim(right_df)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 91791  │ │ string      │ 5     │                                                          │
# │ │ Number of columns │ 7      │ │ int64       │ 1     │                                                          │
# │ └───────────────────┴────────┘ │ float64     │ 1     │                                                          │
# │                                └─────────────┴───────┘                                                          │
# │                                                     number                                                      │
# │ ┏━━━━━━━━━━━━━━━━━┳━━━━━━┳━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━┓  │
# │ ┃ column_name     ┃ NA   ┃ NA %   ┃ mean    ┃ sd      ┃ p0  ┃ p25     ┃ p50     ┃ p75     ┃ p100   ┃ hist    ┃  │
# │ ┡━━━━━━━━━━━━━━━━━╇━━━━━━╇━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━┩  │
# │ │ business_id     │    0 │      0 │   46000 │   26000 │   1 │   23000 │   46000 │   69000 │  92000 │ ▇▇▇▇▇▇  │  │
# │ │ size            │    0 │      0 │     7.3 │      11 │   2 │       3 │       5 │       9 │    500 │    ▇    │  │
# │ └─────────────────┴──────┴────────┴─────────┴─────────┴─────┴─────────┴─────────┴─────────┴────────┴─────────┘  │
# │                                                     string                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┓  │
# │ ┃ column_name               ┃ NA      ┃ NA %       ┃ words per row                ┃ total words              ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━┩  │
# │ │ name                      │       0 │          0 │                          3.8 │                   351853 │  │
# │ │ address                   │       0 │          0 │                          4.1 │                   372729 │  │
# │ │ city                      │       0 │          0 │                          1.3 │                   115386 │  │
# │ │ state                     │       0 │          0 │                            1 │                    91791 │  │
# │ │ zip_code                  │       0 │          0 │                            1 │                    91791 │  │
# │ └───────────────────────────┴─────────┴────────────┴──────────────────────────────┴──────────────────────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯

# %%
import pandas as pd
import recordlinkage
from recordlinkage.preprocessing import clean

# %%
left_df['name'] = clean(left_df['name'])
left_df['address'] = clean(left_df['address'])
left_df['city'] = clean(left_df['city'])
left_df['state'] = clean(left_df['state'])
right_df['name'] = clean(right_df['name'])
right_df['address'] = clean(right_df['address'])
right_df['city'] = clean(right_df['city'])
right_df['state'] = clean(right_df['state'])

# %%
# Handle postal codes as strings directly, stripping any non-numeric parts and padding if necessary
left_df['postal_code'] = left_df['postal_code'].astype(str).apply(lambda x: x.split('.')[0])

# First, ensure the zip_code column is treated as a string
right_df['zip_code'] = right_df['zip_code'].astype(str)

# Process zip_code to keep only the first part before the hyphen and ensure it's 5 digits
right_df['zip_code'] = right_df['zip_code'].apply(lambda x: x.split('-')[0].zfill(5))

left_df.fillna('unknown', inplace=True)

# Rename columns in right_df to match those in left_df
right_df.rename(columns={
    'zip_code': 'postal_code'  
}, inplace=True)

# %%
left_df.head()
# Out:
#    business_id                              name                      address  \
# 0            1              sourini painting inc              12800 44th st n
# 1            2              wolff dolla bill llc              1905 e 19th ave
# 2            3  comprehensive surgery center llc  1988 gulf to bay blvd ste 1
# 3            4            frank adam apparel llc             13640 wright cir
# 4            5         moreno plus transport inc    8608 huron court unite 58
#
#          city state postal_code  size
# 0  clearwater    fl       33762  11.0
# 1       tampa    fl       33605   8.0
# 2  clearwater    fl       33765   8.0
# 3       tampa    fl       33626  12.0
# 4       tampa    fl       33614   8.0

# %%
right_df.head()
# Out:
#    business_id                              name                      address  \
# 0            1              sourini painting inc              12800 44th st n
# 1            2              wolff dolla bill llc              1905 e 19th ave
# 2            3  comprehensive surgery center llc  1988 gulf to bay blvd ste 1
# 3            4            frank adam apparel llc             13640 wright cir
# 4            5         moreno plus transport inc    8608 huron court unite 58
#
#          city state postal_code  size
# 0  clearwater    fl       33762  11.0
# 1       tampa    fl       33605   8.0
# 2  clearwater    fl       33765   8.0
# 3       tampa    fl       33626  12.0
# 4       tampa    fl       33614   8.0

# %%
# Import the recordlinkage module
import recordlinkage

# Create an indexer object
indexer = recordlinkage.Index()

# Add a blocking step: only compare records with the same postal_code
indexer.block('postal_code')

# Generate pairs to compare
candidate_links = indexer.index(left_df, right_df)# Import the Compare module

# %%
# Import the Compare class from the recordlinkage module
from recordlinkage import Compare

# Create a compare object
compare_cl = Compare()

# Define the columns to compare and the method to use
compare_cl.string('name', 'name', method='jarowinkler', threshold=0.85)
compare_cl.string('address', 'address', method='jarowinkler', threshold=0.85)
compare_cl.string('city', 'city', method='jarowinkler', threshold=0.85)
compare_cl.string('state', 'state', method='jarowinkler', threshold=0.85)

# Compute the comparison vectors
features = compare_cl.compute(candidate_links, left_df, right_df)

# %%
features.head()
# Out:
#            0    1    2    3
# 0 36550  0.0  0.0  0.0  1.0
#   36587  0.0  0.0  0.0  1.0
#   36604  0.0  0.0  0.0  1.0
#   36637  0.0  0.0  0.0  1.0
#   36638  0.0  0.0  0.0  1.0

# %%
# Compute the average of the comparison vectors
scores = features.mean(axis=1)

# Create a DataFrame for the matches and their scores
matches_df = pd.DataFrame({'left_index': features.index.get_level_values(0), 'right_index': features.index.get_level_values(1), 'score': scores})

# Filter the matches with a score of 0.8 or higher
high_confidence_matches = matches_df[matches_df['score'] >= 0.8]

# Merge the high-confidence matched records
result = pd.merge(high_confidence_matches, left_df, left_on='left_index', right_index=True)
result = pd.merge(result, right_df, left_on='right_index', right_index=True, suffixes=('_left', '_right'))

# %%
result.head()
# Out:
#           left_index  right_index  score  entity_id           name_left  \
# 7  82926           7        82926    1.0          8      sonic drive in
#    84020           7        84020    1.0          8      sonic drive in
# 56 32736          56        32736    1.0         57          james dant
# 66 77382          66        77382    1.0         67       its sold here
# 76 28231          76        28231    1.0         77  cooks glass mirror
#
#                   address_left     city_left state_left postal_code_left  \
# 7  82926   2312 dickerson pike     nashville         tn            37207
#    84020   2312 dickerson pike     nashville         tn            37207
# 56 32736  5624 e washington st  indianapolis         in            46219
# 66 77382            94 york rd  willow grove         pa            19090
# 76 28231      5703 w morris st  indianapolis         in            46241
#
#                                                  categories  business_id  \
# 7  82926  Ice Cream & Frozen Yogurt, Fast Food, Burgers,...        82927
#    84020  Ice Cream & Frozen Yogurt, Fast Food, Burgers,...        84021
# 56 32736                  Fashion, Shopping, Men's Clothing        32737
# 66 77382              Shopping, Auction Houses, Active Life        77383
# 76 28231  Home Services, Glass & Mirrors, Door Sales/Ins...        28232
#
#                                              name_right         address_right  \
# 7  82926  sonic drive in nashville dickerson road 2 llc   3904 dickerson pike
#    84020    sonic drive in nashville dickerson road llc   2312 dickerson road
# 56 32736                                 james dant llc  5624 e washington st
# 66 77382                                  its sold here          94 york road
# 76 28231                     cooks glass amp mirror inc      5703 w morris st
#
#             city_right state_right postal_code_right  size
# 7  82926     nashville          tn             37207  27.0
#    84020     nashville          tn             37207  21.0
# 56 32736  indianapolis          in             46219   6.0
# 66 77382  willow grove          pa             19090   3.0
# 76 28231  indianapolis          in             46241  10.0
